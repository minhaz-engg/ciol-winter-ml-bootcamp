# %%
import re
import time
import pandas as pd
import torch
import torch.nn as nn
from torch.optim import AdamW
from torch.utils.data import DataLoader, Dataset
from transformers import AutoTokenizer, AutoModel
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
# Define Bangla, Hindi, and English character sets
bangla_chars = 'অআইঈউঊএঐওঔকখগঘঙচছজঝঞটঠডঢণতথদধনপফবভমযরলশষসহড়ঢ়য়ৠৡ০১২৩৪৫৬৭৮৯'
hindi_chars = 'अआइईउऊऋएऐओऔकखगघङचछजझञटठडढणतथदधनपफबभमयरलशषसह०१२३४५६७८९'
english_chars = 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
# Function to detect the dominant language in a text
def detect_dominant_language(text):
    bangla_count = 0
    hindi_count = 0
    english_count = 0

    # Split text into words
    words = re.findall(r'\b\w+\b', text)

    # Count the words for each language
    for word in words:
        if any(char in bangla_chars for char in word):
            bangla_count += 1
        elif any(char in hindi_chars for char in word):
            hindi_count += 1
        elif any(char in english_chars for char in word):
            english_count += 1

    # Determine the dominant language
    counts = {'Bangla': bangla_count, 'Hindi': hindi_count, 'English': english_count}
    dominant_language = max(counts, key=counts.get)

    return dominant_language

# %%
# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Load Dataset
data = pd.read_csv("/kaggle/input/100k-bangla-english-hindi-sentiment/option 4.csv")

# %%
# Handle missing values
data = data.dropna().reset_index(drop=True)

# %%
# Add `text_length` and `language` columns
data["text_length"] = data["text"].apply(len)
data["language"] = data["text"].apply(detect_dominant_language)

# %%
data
# Out:
#           label                                               text  \
# 0      Negative  DO NOT let the blu ray symbol on the box fool ...
# 1       Neutral  আমার কোন ভাগ্য ছিল না trying to recover my फ़ा...
# 2      Negative  यह बात वाकई में उलझ सकती है your computer. Che...
# 3      Negative  मैं टर्बो लोड नहीं कर सकता Tax 22015 on Window...
# 4       Neutral  It's okay, but not as good as the মাইক্রোসফ্ট ...
# ...         ...                                                ...
# 59989   Neutral  it is extremely cumbersome to navigate. while ...
# 59990  Positive  some say it's hard to load. you need आपके पास ...
# 59991  Negative  मैंने पिछले 3 वर्षों से टर्बोटैक्स का उपयोग कि...
# 59992  Negative  यदि आप कर करने के लिए इस सॉफ़्टवेयर का उपयोग क...
# 59993   Neutral  I've done enough backup restores to learn that...
#
#        text_length language
# 0              388    Hindi
# 1              126    Hindi
# 2              169   Bangla
# 3              159    Hindi
# 4              253    Hindi
# ...            ...      ...
# 59989          397    Hindi
# 59990          218    Hindi
# 59991         1918    Hindi
# 59992          771    Hindi
# 59993         4485    Hindi
#
# [59994 rows x 4 columns]

# %%
# Group by label and language, and calculate average text length
avg_text_length = data.groupby(['label', 'language'])['text_length'].mean()

# Print the result
print(avg_text_length)
# Out:
# label     language
# Negative  Bangla      555.763115
#           English     589.500000
#           Hindi       557.917066
# Neutral   Bangla      563.324702
#           English     612.340470
#           Hindi       555.606427
# Positive  Bangla      352.785996
#           English     429.512168
#           Hindi       366.801426
# Name: text_length, dtype: float64

# %%
# Encode `label` and `language`
label_map = {"Negative": 0, "Neutral": 1, "Positive": 2}
data["label"] = data["label"].map(label_map)

language_map = {"Bangla": 0, "Hindi": 1, "English": 2}
data["language_encoded"] = data["language"].map(language_map)

# %%
character_limit = 512

# %%
# Filter long texts and reset index
data = data[data["text_length"] <= character_limit].reset_index(drop=True)

# %%
# Split dataset into train, validation, and test sets
train_texts, test_texts, train_labels, test_labels = train_test_split(
    data["text"], data["label"], test_size=0.1, random_state=42
)
train_texts, val_texts, train_labels, val_labels = train_test_split(
    train_texts, train_labels, test_size=0.1, random_state=42
)

# %%
# Corresponding lengths and languages
train_texts_length = data.loc[train_texts.index, "text_length"]
val_texts_length = data.loc[val_texts.index, "text_length"]
test_texts_length = data.loc[test_texts.index, "text_length"]

train_texts_language = data.loc[train_texts.index, "language_encoded"]
val_texts_language = data.loc[val_texts.index, "language_encoded"]
test_texts_language = data.loc[test_texts.index, "language_encoded"]

# %%
# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained("xlm-roberta-base")
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
# Tokenize data
def tokenize_data_with_features(texts, lengths, languages, labels, max_length=character_limit):
    encodings = tokenizer(list(texts), truncation=True, padding=True, max_length=max_length)
    encodings["text_length"] = torch.tensor(lengths.values, dtype=torch.float32)
    encodings["language"] = torch.tensor(languages.values, dtype=torch.long)
    return encodings, torch.tensor(labels.values)

train_encodings, train_labels = tokenize_data_with_features(train_texts, train_texts_length, train_texts_language, train_labels)
val_encodings, val_labels = tokenize_data_with_features(val_texts, val_texts_length, val_texts_language, val_labels)
test_encodings, test_labels = tokenize_data_with_features(test_texts, test_texts_length, test_texts_language, test_labels)

# %%
# Custom Dataset class
class SentimentDataset(Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item["labels"] = self.labels[idx]
        return item

# %%
train_dataset = SentimentDataset(train_encodings, train_labels)
val_dataset = SentimentDataset(val_encodings, val_labels)
test_dataset = SentimentDataset(test_encodings, test_labels)

# %%
# Define the model
class SentimentClassifier(nn.Module):
    def __init__(self, model_name, num_labels, extra_features=2):
        super(SentimentClassifier, self).__init__()
        self.bert = AutoModel.from_pretrained(model_name)
        self.classifier = nn.Linear(self.bert.config.hidden_size + extra_features, num_labels)

    def forward(self, input_ids, attention_mask, text_length, language):
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        cls_output = outputs.last_hidden_state[:, 0, :]  # CLS token
        combined_features = torch.cat([cls_output, text_length.unsqueeze(1), language.unsqueeze(1)], dim=1)
        logits = self.classifier(combined_features)
        return logits

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SentimentClassifier("xlm-roberta-base", num_labels=3).to(device)
# Out:
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]

# %%
# Training setup
batch_size = 16
learning_rate = 1e-5

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

optimizer = AdamW(model.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss()

# %%
# Training loop
batch_see = 100

def train_model(model, train_loader, val_loader, epochs):
    for epoch in range(epochs):
        epoch_start_time = time.time()
        model.train()
        train_loss = 0
        correct, total = 0, 0
        
        for batch_idx, batch in enumerate(train_loader):
            
            if (batch_idx + 1) % batch_see == 1:
                batch_start_time = time.time()

            
            optimizer.zero_grad()
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            text_length = batch["text_length"].to(device)
            language = batch["language"].to(device)
            labels = batch["labels"].to(device)

            outputs = model(input_ids, attention_mask, text_length, language)
            loss = criterion(outputs, labels)
            train_loss += loss.item()

            loss.backward()
            optimizer.step()

            preds = torch.argmax(outputs, dim=1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

            if (batch_idx + 1) % batch_see == 0:  # Display progress every 10 batches
                batch_time = time.time() - batch_start_time
                batch_time_str = time.strftime('%H:%M:%S', time.gmtime(batch_time))
                print(f"Epoch [{epoch + 1}/{epochs}], Step [{batch_idx + 1}/{len(train_loader)}], Loss: {loss.item():.4f}, Accuracy: {correct / total:.4f}, time = {batch_time_str}")

            
        val_loss = 0
        val_correct, val_total = 0, 0
        model.eval()
        with torch.no_grad():
            for batch in val_loader:
                input_ids = batch["input_ids"].to(device)
                attention_mask = batch["attention_mask"].to(device)
                text_length = batch["text_length"].to(device)
                language = batch["language"].to(device)
                labels = batch["labels"].to(device)

                outputs = model(input_ids, attention_mask, text_length, language)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds == labels).sum().item()
                val_total += labels.size(0)

        epoch_time = time.time() - epoch_start_time
        epoch_time_str = time.strftime('%H:%M:%S', time.gmtime(epoch_time))
        print(f"Epoch {epoch + 1}/{epochs}, Train Loss: {train_loss / len(train_loader):.4f}, "
              f"Train Accuracy: {correct / total:.4f}, Val Loss: {val_loss / len(val_loader):.4f}, "
              f"Val Accuracy: {val_correct / val_total:.4f}, Time Spent = {epoch_time_str}")

# %%
train_model(model, train_loader, val_loader, epochs=15)
# Out:
# <ipython-input-17-47be11e0a1ba>:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Epoch [1/15], Step [100/2142], Loss: 1.1770, Accuracy: 0.3850, time = 00:00:35
# Epoch [1/15], Step [200/2142], Loss: 1.1545, Accuracy: 0.3972, time = 00:00:34
# Epoch [1/15], Step [300/2142], Loss: 1.0107, Accuracy: 0.4000, time = 00:00:34
# Epoch [1/15], Step [400/2142], Loss: 1.2808, Accuracy: 0.4044, time = 00:00:34
# Epoch [1/15], Step [500/2142], Loss: 0.9840, Accuracy: 0.4265, time = 00:00:35
# Epoch [1/15], Step [600/2142], Loss: 0.5377, Accuracy: 0.4519, time = 00:00:35
# Epoch [1/15], Step [700/2142], Loss: 1.1638, Accuracy: 0.4811, time = 00:00:35
# Epoch [1/15], Step [800/2142], Loss: 0.6925, Accuracy: 0.5033, time = 00:00:35
# Epoch [1/15], Step [900/2142], Loss: 0.5908, Accuracy: 0.5217, time = 00:00:35
# Epoch [1/15], Step [1000/2142], Loss: 0.7714, Accuracy: 0.5391, time = 00:00:35
# Epoch [1/15], Step [1100/2142], Loss: 0.8334, Accuracy: 0.5524, time = 00:00:35
# Epoch [1/15], Step [1200/2142], Loss: 0.5653, Accuracy: 0.5645, time = 00:00:35
# Epoch [1/15], Step [1300/2142], Loss: 0.5360, Accuracy: 0.5761, time = 00:00:35
# Epoch [1/15], Step [1400/2142], Loss: 0.4613, Accuracy: 0.5867, time = 00:00:35
# Epoch [1/15], Step [1500/2142], Loss: 0.8382, Accuracy: 0.5930, time = 00:00:35
# Epoch [1/15], Step [1600/2142], Loss: 0.3416, Accuracy: 0.5996, time = 00:00:35
# Epoch [1/15], Step [1700/2142], Loss: 0.4901, Accuracy: 0.6078, time = 00:00:35
# Epoch [1/15], Step [1800/2142], Loss: 0.7292, Accuracy: 0.6135, time = 00:00:35
# Epoch [1/15], Step [1900/2142], Loss: 0.6930, Accuracy: 0.6188, time = 00:00:35
# Epoch [1/15], Step [2000/2142], Loss: 0.4540, Accuracy: 0.6237, time = 00:00:35
# Epoch [1/15], Step [2100/2142], Loss: 0.4150, Accuracy: 0.6288, time = 00:00:35
# Epoch 1/15, Train Loss: 0.8234, Train Accuracy: 0.6315, Val Loss: 0.6397, Val Accuracy: 0.7274, Time Spent = 00:12:58
# Epoch [2/15], Step [100/2142], Loss: 0.4332, Accuracy: 0.7606, time = 00:00:35
# Epoch [2/15], Step [200/2142], Loss: 0.5619, Accuracy: 0.7531, time = 00:00:35
# Epoch [2/15], Step [300/2142], Loss: 0.4622, Accuracy: 0.7452, time = 00:00:35
# Epoch [2/15], Step [400/2142], Loss: 0.6633, Accuracy: 0.7464, time = 00:00:35
# Epoch [2/15], Step [500/2142], Loss: 0.3749, Accuracy: 0.7480, time = 00:00:35
# Epoch [2/15], Step [600/2142], Loss: 0.4568, Accuracy: 0.7498, time = 00:00:35
# Epoch [2/15], Step [700/2142], Loss: 0.4592, Accuracy: 0.7524, time = 00:00:35
# Epoch [2/15], Step [800/2142], Loss: 0.7189, Accuracy: 0.7528, time = 00:00:35
# Epoch [2/15], Step [900/2142], Loss: 0.6255, Accuracy: 0.7540, time = 00:00:35
# Epoch [2/15], Step [1000/2142], Loss: 0.6822, Accuracy: 0.7548, time = 00:00:35
# Epoch [2/15], Step [1100/2142], Loss: 0.5245, Accuracy: 0.7552, time = 00:00:35
# Epoch [2/15], Step [1200/2142], Loss: 0.6388, Accuracy: 0.7546, time = 00:00:35
# Epoch [2/15], Step [1300/2142], Loss: 0.5098, Accuracy: 0.7540, time = 00:00:35
# Epoch [2/15], Step [1400/2142], Loss: 0.6138, Accuracy: 0.7536, time = 00:00:35
# Epoch [2/15], Step [1500/2142], Loss: 0.4677, Accuracy: 0.7549, time = 00:00:35
# Epoch [2/15], Step [1600/2142], Loss: 0.4726, Accuracy: 0.7548, time = 00:00:35
# Epoch [2/15], Step [1700/2142], Loss: 0.3606, Accuracy: 0.7550, time = 00:00:35
# Epoch [2/15], Step [1800/2142], Loss: 0.5458, Accuracy: 0.7555, time = 00:00:35
# Epoch [2/15], Step [1900/2142], Loss: 1.0686, Accuracy: 0.7562, time = 00:00:35
# Epoch [2/15], Step [2000/2142], Loss: 0.4301, Accuracy: 0.7567, time = 00:00:35
# Epoch [2/15], Step [2100/2142], Loss: 0.7266, Accuracy: 0.7574, time = 00:00:35
# Epoch 2/15, Train Loss: 0.5741, Train Accuracy: 0.7577, Val Loss: 0.6041, Val Accuracy: 0.7489, Time Spent = 00:13:02
# Epoch [3/15], Step [100/2142], Loss: 0.6386, Accuracy: 0.7950, time = 00:00:35
# Epoch [3/15], Step [200/2142], Loss: 0.5817, Accuracy: 0.7837, time = 00:00:35
# Epoch [3/15], Step [300/2142], Loss: 0.4555, Accuracy: 0.7848, time = 00:00:35
# Epoch [3/15], Step [400/2142], Loss: 0.2903, Accuracy: 0.7834, time = 00:00:35
# Epoch [3/15], Step [500/2142], Loss: 0.7818, Accuracy: 0.7826, time = 00:00:35
# Epoch [3/15], Step [600/2142], Loss: 0.6446, Accuracy: 0.7809, time = 00:00:35
# Epoch [3/15], Step [700/2142], Loss: 0.4864, Accuracy: 0.7791, time = 00:00:35
# Epoch [3/15], Step [800/2142], Loss: 0.5736, Accuracy: 0.7805, time = 00:00:35
# Epoch [3/15], Step [900/2142], Loss: 0.4362, Accuracy: 0.7828, time = 00:00:35
# Epoch [3/15], Step [1000/2142], Loss: 0.5462, Accuracy: 0.7818, time = 00:00:35
# Epoch [3/15], Step [1100/2142], Loss: 0.4322, Accuracy: 0.7832, time = 00:00:35
# Epoch [3/15], Step [1200/2142], Loss: 0.2195, Accuracy: 0.7838, time = 00:00:35
# Epoch [3/15], Step [1300/2142], Loss: 0.8593, Accuracy: 0.7851, time = 00:00:35
# Epoch [3/15], Step [1400/2142], Loss: 0.4175, Accuracy: 0.7865, time = 00:00:35
# Epoch [3/15], Step [1500/2142], Loss: 0.4691, Accuracy: 0.7865, time = 00:00:35
# Epoch [3/15], Step [1600/2142], Loss: 0.9482, Accuracy: 0.7865, time = 00:00:35
# Epoch [3/15], Step [1700/2142], Loss: 0.3700, Accuracy: 0.7857, time = 00:00:35
# Epoch [3/15], Step [1800/2142], Loss: 0.3840, Accuracy: 0.7858, time = 00:00:35
# Epoch [3/15], Step [1900/2142], Loss: 0.6419, Accuracy: 0.7861, time = 00:00:35
# Epoch [3/15], Step [2000/2142], Loss: 0.3703, Accuracy: 0.7869, time = 00:00:35
# Epoch [3/15], Step [2100/2142], Loss: 0.4033, Accuracy: 0.7863, time = 00:00:35
# Epoch 3/15, Train Loss: 0.5167, Train Accuracy: 0.7862, Val Loss: 0.5877, Val Accuracy: 0.7513, Time Spent = 00:13:00
# Epoch [4/15], Step [100/2142], Loss: 0.3225, Accuracy: 0.8300, time = 00:00:35
# Epoch [4/15], Step [200/2142], Loss: 0.7977, Accuracy: 0.8344, time = 00:00:35
# Epoch [4/15], Step [300/2142], Loss: 0.2857, Accuracy: 0.8337, time = 00:00:35
# Epoch [4/15], Step [400/2142], Loss: 0.2738, Accuracy: 0.8263, time = 00:00:35
# Epoch [4/15], Step [500/2142], Loss: 0.6223, Accuracy: 0.8245, time = 00:00:35
# Epoch [4/15], Step [600/2142], Loss: 0.3512, Accuracy: 0.8206, time = 00:00:35
# Epoch [4/15], Step [700/2142], Loss: 0.4688, Accuracy: 0.8227, time = 00:00:35
# Epoch [4/15], Step [800/2142], Loss: 0.1697, Accuracy: 0.8215, time = 00:00:35
# Epoch [4/15], Step [900/2142], Loss: 0.4066, Accuracy: 0.8199, time = 00:00:35
# Epoch [4/15], Step [1000/2142], Loss: 0.2825, Accuracy: 0.8187, time = 00:00:35
# Epoch [4/15], Step [1100/2142], Loss: 0.3228, Accuracy: 0.8183, time = 00:00:35
# Epoch [4/15], Step [1200/2142], Loss: 0.4783, Accuracy: 0.8185, time = 00:00:35
# Epoch [4/15], Step [1300/2142], Loss: 0.2347, Accuracy: 0.8173, time = 00:00:35
# Epoch [4/15], Step [1400/2142], Loss: 0.5699, Accuracy: 0.8184, time = 00:00:35
# Epoch [4/15], Step [1500/2142], Loss: 0.4273, Accuracy: 0.8195, time = 00:00:35
# Epoch [4/15], Step [1600/2142], Loss: 0.6447, Accuracy: 0.8201, time = 00:00:35
# Epoch [4/15], Step [1700/2142], Loss: 0.5819, Accuracy: 0.8201, time = 00:00:35
# Epoch [4/15], Step [1800/2142], Loss: 0.4782, Accuracy: 0.8193, time = 00:00:35
# Epoch [4/15], Step [1900/2142], Loss: 0.2833, Accuracy: 0.8195, time = 00:00:35
# Epoch [4/15], Step [2000/2142], Loss: 0.5754, Accuracy: 0.8192, time = 00:00:35
# Epoch [4/15], Step [2100/2142], Loss: 0.4448, Accuracy: 0.8193, time = 00:00:35
# Epoch 4/15, Train Loss: 0.4404, Train Accuracy: 0.8194, Val Loss: 0.6798, Val Accuracy: 0.7566, Time Spent = 00:12:59
# Epoch [5/15], Step [100/2142], Loss: 0.3954, Accuracy: 0.8644, time = 00:00:35
# Epoch [5/15], Step [200/2142], Loss: 0.0732, Accuracy: 0.8538, time = 00:00:35
# Epoch [5/15], Step [300/2142], Loss: 0.3390, Accuracy: 0.8573, time = 00:00:35
# Epoch [5/15], Step [400/2142], Loss: 0.2680, Accuracy: 0.8566, time = 00:00:35
# Epoch [5/15], Step [500/2142], Loss: 0.5768, Accuracy: 0.8552, time = 00:00:35
# Epoch [5/15], Step [600/2142], Loss: 0.4091, Accuracy: 0.8539, time = 00:00:35
# Epoch [5/15], Step [700/2142], Loss: 0.1953, Accuracy: 0.8521, time = 00:00:35
# Epoch [5/15], Step [800/2142], Loss: 0.2924, Accuracy: 0.8530, time = 00:00:35
# Epoch [5/15], Step [900/2142], Loss: 0.3055, Accuracy: 0.8533, time = 00:00:35
# Epoch [5/15], Step [1000/2142], Loss: 0.2166, Accuracy: 0.8531, time = 00:00:35
# Epoch [5/15], Step [1100/2142], Loss: 0.1689, Accuracy: 0.8521, time = 00:00:35
# Epoch [5/15], Step [1200/2142], Loss: 0.2353, Accuracy: 0.8515, time = 00:00:35
# Epoch [5/15], Step [1300/2142], Loss: 0.0922, Accuracy: 0.8518, time = 00:00:35
# Epoch [5/15], Step [1400/2142], Loss: 0.2081, Accuracy: 0.8517, time = 00:00:35
# Epoch [5/15], Step [1500/2142], Loss: 0.4543, Accuracy: 0.8514, time = 00:00:35
# Epoch [5/15], Step [1600/2142], Loss: 0.3797, Accuracy: 0.8510, time = 00:00:35
# Epoch [5/15], Step [1700/2142], Loss: 0.6156, Accuracy: 0.8503, time = 00:00:35
# Epoch [5/15], Step [1800/2142], Loss: 0.2889, Accuracy: 0.8501, time = 00:00:35
# Epoch [5/15], Step [1900/2142], Loss: 0.3203, Accuracy: 0.8504, time = 00:00:35
# Epoch [5/15], Step [2000/2142], Loss: 0.5735, Accuracy: 0.8503, time = 00:00:35
# Epoch [5/15], Step [2100/2142], Loss: 1.0601, Accuracy: 0.8502, time = 00:00:35
# Epoch 5/15, Train Loss: 0.3782, Train Accuracy: 0.8506, Val Loss: 0.6733, Val Accuracy: 0.7513, Time Spent = 00:12:59
# Epoch [6/15], Step [100/2142], Loss: 0.1963, Accuracy: 0.8794, time = 00:00:35
# Epoch [6/15], Step [200/2142], Loss: 0.2209, Accuracy: 0.8788, time = 00:00:35
# Epoch [6/15], Step [300/2142], Loss: 0.0439, Accuracy: 0.8833, time = 00:00:35
# Epoch [6/15], Step [400/2142], Loss: 0.1458, Accuracy: 0.8834, time = 00:00:35
# Epoch [6/15], Step [500/2142], Loss: 0.1149, Accuracy: 0.8842, time = 00:00:35
# Epoch [6/15], Step [600/2142], Loss: 0.3976, Accuracy: 0.8835, time = 00:00:35
# Epoch [6/15], Step [700/2142], Loss: 0.1324, Accuracy: 0.8821, time = 00:00:35
# Epoch [6/15], Step [800/2142], Loss: 0.2521, Accuracy: 0.8816, time = 00:00:35
# Epoch [6/15], Step [900/2142], Loss: 0.1022, Accuracy: 0.8805, time = 00:00:35
# Epoch [6/15], Step [1000/2142], Loss: 0.3069, Accuracy: 0.8818, time = 00:00:35
# Epoch [6/15], Step [1100/2142], Loss: 0.2344, Accuracy: 0.8814, time = 00:00:35
# Epoch [6/15], Step [1200/2142], Loss: 0.5927, Accuracy: 0.8808, time = 00:00:35
# Epoch [6/15], Step [1300/2142], Loss: 0.1478, Accuracy: 0.8812, time = 00:00:35
# Epoch [6/15], Step [1400/2142], Loss: 0.2110, Accuracy: 0.8808, time = 00:00:35
# Epoch [6/15], Step [1500/2142], Loss: 0.1645, Accuracy: 0.8799, time = 00:00:35
# Epoch [6/15], Step [1600/2142], Loss: 0.2470, Accuracy: 0.8795, time = 00:00:35
# Epoch [6/15], Step [1700/2142], Loss: 0.1951, Accuracy: 0.8789, time = 00:00:35
# Epoch [6/15], Step [1800/2142], Loss: 0.3674, Accuracy: 0.8776, time = 00:00:35
# Epoch [6/15], Step [1900/2142], Loss: 0.0948, Accuracy: 0.8767, time = 00:00:35
# Epoch [6/15], Step [2000/2142], Loss: 0.7856, Accuracy: 0.8773, time = 00:00:35
# Epoch [6/15], Step [2100/2142], Loss: 0.3915, Accuracy: 0.8773, time = 00:00:35
# Epoch 6/15, Train Loss: 0.3186, Train Accuracy: 0.8771, Val Loss: 0.7427, Val Accuracy: 0.7518, Time Spent = 00:12:59
# Epoch [7/15], Step [100/2142], Loss: 0.1526, Accuracy: 0.9081, time = 00:00:35
# Epoch [7/15], Step [200/2142], Loss: 0.0976, Accuracy: 0.9097, time = 00:00:35
# Epoch [7/15], Step [300/2142], Loss: 0.1481, Accuracy: 0.9069, time = 00:00:35
# Epoch [7/15], Step [400/2142], Loss: 0.1577, Accuracy: 0.9052, time = 00:00:35
# Epoch [7/15], Step [500/2142], Loss: 0.3091, Accuracy: 0.9042, time = 00:00:35
# Epoch [7/15], Step [600/2142], Loss: 0.2449, Accuracy: 0.9030, time = 00:00:35
# Epoch [7/15], Step [700/2142], Loss: 0.0874, Accuracy: 0.9041, time = 00:00:35
# Epoch [7/15], Step [800/2142], Loss: 0.1852, Accuracy: 0.9008, time = 00:00:35
# Epoch [7/15], Step [900/2142], Loss: 0.3702, Accuracy: 0.9008, time = 00:00:35
# Epoch [7/15], Step [1000/2142], Loss: 0.3349, Accuracy: 0.9026, time = 00:00:35
# Epoch [7/15], Step [1100/2142], Loss: 0.2855, Accuracy: 0.9020, time = 00:00:35
# Epoch [7/15], Step [1200/2142], Loss: 0.2514, Accuracy: 0.9009, time = 00:00:35
# Epoch [7/15], Step [1300/2142], Loss: 0.1525, Accuracy: 0.9006, time = 00:00:35
# Epoch [7/15], Step [1400/2142], Loss: 0.3022, Accuracy: 0.9004, time = 00:00:35
# Epoch [7/15], Step [1500/2142], Loss: 0.0569, Accuracy: 0.8993, time = 00:00:35
# Epoch [7/15], Step [1600/2142], Loss: 0.4923, Accuracy: 0.8990, time = 00:00:35
# Epoch [7/15], Step [1700/2142], Loss: 0.1403, Accuracy: 0.8994, time = 00:00:35
# Epoch [7/15], Step [1800/2142], Loss: 0.0495, Accuracy: 0.8984, time = 00:00:35
# Epoch [7/15], Step [1900/2142], Loss: 0.6594, Accuracy: 0.8989, time = 00:00:35
# Epoch [7/15], Step [2000/2142], Loss: 0.1600, Accuracy: 0.8987, time = 00:00:35
# Epoch [7/15], Step [2100/2142], Loss: 0.1352, Accuracy: 0.8990, time = 00:00:35
# Epoch 7/15, Train Loss: 0.2653, Train Accuracy: 0.8987, Val Loss: 0.8000, Val Accuracy: 0.7447, Time Spent = 00:12:59
# Epoch [8/15], Step [100/2142], Loss: 0.1571, Accuracy: 0.9313, time = 00:00:35
# Epoch [8/15], Step [200/2142], Loss: 0.1365, Accuracy: 0.9253, time = 00:00:35
# Epoch [8/15], Step [300/2142], Loss: 0.2663, Accuracy: 0.9240, time = 00:00:35
# Epoch [8/15], Step [400/2142], Loss: 0.7821, Accuracy: 0.9253, time = 00:00:35
# Epoch [8/15], Step [500/2142], Loss: 0.1233, Accuracy: 0.9277, time = 00:00:35
# Epoch [8/15], Step [600/2142], Loss: 0.5011, Accuracy: 0.9287, time = 00:00:35
# Epoch [8/15], Step [700/2142], Loss: 0.5229, Accuracy: 0.9271, time = 00:00:35
# Epoch [8/15], Step [800/2142], Loss: 0.1977, Accuracy: 0.9263, time = 00:00:35
# Epoch [8/15], Step [900/2142], Loss: 0.0434, Accuracy: 0.9253, time = 00:00:35
# Epoch [8/15], Step [1000/2142], Loss: 0.3843, Accuracy: 0.9241, time = 00:00:35
# Epoch [8/15], Step [1100/2142], Loss: 0.1083, Accuracy: 0.9240, time = 00:00:35
# Epoch [8/15], Step [1200/2142], Loss: 0.1361, Accuracy: 0.9234, time = 00:00:35
# Epoch [8/15], Step [1300/2142], Loss: 0.2699, Accuracy: 0.9226, time = 00:00:35
# Epoch [8/15], Step [1400/2142], Loss: 0.1260, Accuracy: 0.9232, time = 00:00:35
# Epoch [8/15], Step [1500/2142], Loss: 0.2316, Accuracy: 0.9222, time = 00:00:35
# Epoch [8/15], Step [1600/2142], Loss: 0.0671, Accuracy: 0.9212, time = 00:00:35
# Epoch [8/15], Step [1700/2142], Loss: 0.4056, Accuracy: 0.9203, time = 00:00:35
# Epoch [8/15], Step [1800/2142], Loss: 0.4124, Accuracy: 0.9209, time = 00:00:35
# Epoch [8/15], Step [1900/2142], Loss: 0.3935, Accuracy: 0.9206, time = 00:00:35
# Epoch [8/15], Step [2000/2142], Loss: 0.2049, Accuracy: 0.9201, time = 00:00:35
# Epoch [8/15], Step [2100/2142], Loss: 0.2505, Accuracy: 0.9201, time = 00:00:35
# Epoch 8/15, Train Loss: 0.2161, Train Accuracy: 0.9201, Val Loss: 0.9319, Val Accuracy: 0.7411, Time Spent = 00:12:59
# Epoch [9/15], Step [100/2142], Loss: 0.0525, Accuracy: 0.9475, time = 00:00:35
# Epoch [9/15], Step [200/2142], Loss: 0.0497, Accuracy: 0.9444, time = 00:00:35
# Epoch [9/15], Step [300/2142], Loss: 0.1371, Accuracy: 0.9431, time = 00:00:35
# Epoch [9/15], Step [400/2142], Loss: 0.1200, Accuracy: 0.9423, time = 00:00:35
# Epoch [9/15], Step [500/2142], Loss: 0.0147, Accuracy: 0.9423, time = 00:00:35
# Epoch [9/15], Step [600/2142], Loss: 0.1339, Accuracy: 0.9406, time = 00:00:35
# Epoch [9/15], Step [700/2142], Loss: 0.3506, Accuracy: 0.9389, time = 00:00:35
# Epoch [9/15], Step [800/2142], Loss: 0.1272, Accuracy: 0.9384, time = 00:00:35
# Epoch [9/15], Step [900/2142], Loss: 0.0317, Accuracy: 0.9383, time = 00:00:35
# Epoch [9/15], Step [1000/2142], Loss: 0.0669, Accuracy: 0.9384, time = 00:00:35
# Epoch [9/15], Step [1100/2142], Loss: 0.0557, Accuracy: 0.9377, time = 00:00:35
# Epoch [9/15], Step [1200/2142], Loss: 0.3751, Accuracy: 0.9374, time = 00:00:35
# Epoch [9/15], Step [1300/2142], Loss: 0.1267, Accuracy: 0.9367, time = 00:00:35
# Epoch [9/15], Step [1400/2142], Loss: 0.1723, Accuracy: 0.9360, time = 00:00:35
# Epoch [9/15], Step [1500/2142], Loss: 0.2208, Accuracy: 0.9359, time = 00:00:35
# Epoch [9/15], Step [1600/2142], Loss: 0.0496, Accuracy: 0.9350, time = 00:00:35
# Epoch [9/15], Step [1700/2142], Loss: 0.4096, Accuracy: 0.9354, time = 00:00:35
# Epoch [9/15], Step [1800/2142], Loss: 0.2159, Accuracy: 0.9348, time = 00:00:35
# Epoch [9/15], Step [1900/2142], Loss: 0.0966, Accuracy: 0.9349, time = 00:00:35
# Epoch [9/15], Step [2000/2142], Loss: 0.2578, Accuracy: 0.9346, time = 00:00:35
# Epoch [9/15], Step [2100/2142], Loss: 0.4111, Accuracy: 0.9344, time = 00:00:35
# Epoch 9/15, Train Loss: 0.1809, Train Accuracy: 0.9341, Val Loss: 0.9201, Val Accuracy: 0.7413, Time Spent = 00:13:00
# Epoch [10/15], Step [100/2142], Loss: 0.0891, Accuracy: 0.9537, time = 00:00:35
# Epoch [10/15], Step [200/2142], Loss: 0.0522, Accuracy: 0.9478, time = 00:00:35
# Epoch [10/15], Step [300/2142], Loss: 0.0430, Accuracy: 0.9435, time = 00:00:35
# Epoch [10/15], Step [400/2142], Loss: 0.0220, Accuracy: 0.9448, time = 00:00:35
# Epoch [10/15], Step [500/2142], Loss: 0.0301, Accuracy: 0.9449, time = 00:00:35
# Epoch [10/15], Step [600/2142], Loss: 0.4768, Accuracy: 0.9425, time = 00:00:35
# Epoch [10/15], Step [700/2142], Loss: 0.1268, Accuracy: 0.9428, time = 00:00:35
# Epoch [10/15], Step [800/2142], Loss: 0.0839, Accuracy: 0.9419, time = 00:00:35
# Epoch [10/15], Step [900/2142], Loss: 0.2724, Accuracy: 0.9423, time = 00:00:35
# Epoch [10/15], Step [1000/2142], Loss: 0.0459, Accuracy: 0.9436, time = 00:00:35
# Epoch [10/15], Step [1100/2142], Loss: 0.3322, Accuracy: 0.9439, time = 00:00:35
# Epoch [10/15], Step [1200/2142], Loss: 0.4003, Accuracy: 0.9434, time = 00:00:35
# Epoch [10/15], Step [1300/2142], Loss: 0.1159, Accuracy: 0.9431, time = 00:00:35
# Epoch [10/15], Step [1400/2142], Loss: 0.0912, Accuracy: 0.9435, time = 00:00:35
# Epoch [10/15], Step [1500/2142], Loss: 0.6134, Accuracy: 0.9427, time = 00:00:35
# Epoch [10/15], Step [1600/2142], Loss: 0.1014, Accuracy: 0.9418, time = 00:00:35
# Epoch [10/15], Step [1700/2142], Loss: 0.1352, Accuracy: 0.9418, time = 00:00:35
# Epoch [10/15], Step [1800/2142], Loss: 0.0651, Accuracy: 0.9418, time = 00:00:35
# Epoch [10/15], Step [1900/2142], Loss: 0.1109, Accuracy: 0.9415, time = 00:00:35
# Epoch [10/15], Step [2000/2142], Loss: 0.0272, Accuracy: 0.9412, time = 00:00:35
# Epoch [10/15], Step [2100/2142], Loss: 0.0831, Accuracy: 0.9415, time = 00:00:35
# Epoch 10/15, Train Loss: 0.1598, Train Accuracy: 0.9414, Val Loss: 1.0645, Val Accuracy: 0.7395, Time Spent = 00:12:59
# Epoch [11/15], Step [100/2142], Loss: 0.1711, Accuracy: 0.9519, time = 00:00:35
# Epoch [11/15], Step [200/2142], Loss: 0.0723, Accuracy: 0.9537, time = 00:00:35
# Epoch [11/15], Step [300/2142], Loss: 0.0553, Accuracy: 0.9519, time = 00:00:35
# Epoch [11/15], Step [400/2142], Loss: 0.0259, Accuracy: 0.9516, time = 00:00:35
# Epoch [11/15], Step [500/2142], Loss: 0.1317, Accuracy: 0.9519, time = 00:00:35
# Epoch [11/15], Step [600/2142], Loss: 0.0917, Accuracy: 0.9507, time = 00:00:35
# Epoch [11/15], Step [700/2142], Loss: 0.1706, Accuracy: 0.9503, time = 00:00:35
# Epoch [11/15], Step [800/2142], Loss: 0.3054, Accuracy: 0.9506, time = 00:00:35
# Epoch [11/15], Step [900/2142], Loss: 0.3354, Accuracy: 0.9506, time = 00:00:35
# Epoch [11/15], Step [1000/2142], Loss: 0.1289, Accuracy: 0.9517, time = 00:00:35
# Epoch [11/15], Step [1100/2142], Loss: 0.3220, Accuracy: 0.9519, time = 00:00:35
# Epoch [11/15], Step [1200/2142], Loss: 0.2719, Accuracy: 0.9517, time = 00:00:35
# Epoch [11/15], Step [1300/2142], Loss: 0.0141, Accuracy: 0.9524, time = 00:00:35
# Epoch [11/15], Step [1400/2142], Loss: 0.3700, Accuracy: 0.9529, time = 00:00:35
# Epoch [11/15], Step [1500/2142], Loss: 0.2074, Accuracy: 0.9525, time = 00:00:35
# Epoch [11/15], Step [1600/2142], Loss: 0.0048, Accuracy: 0.9527, time = 00:00:35
# Epoch [11/15], Step [1700/2142], Loss: 0.0450, Accuracy: 0.9524, time = 00:00:35
# Epoch [11/15], Step [1800/2142], Loss: 0.0436, Accuracy: 0.9525, time = 00:00:35
# Epoch [11/15], Step [1900/2142], Loss: 0.0492, Accuracy: 0.9522, time = 00:00:35
# Epoch [11/15], Step [2000/2142], Loss: 0.0500, Accuracy: 0.9525, time = 00:00:35
# Epoch [11/15], Step [2100/2142], Loss: 0.1089, Accuracy: 0.9520, time = 00:00:35
# Epoch 11/15, Train Loss: 0.1317, Train Accuracy: 0.9519, Val Loss: 1.1200, Val Accuracy: 0.7413, Time Spent = 00:12:59
# Epoch [12/15], Step [100/2142], Loss: 0.1306, Accuracy: 0.9669, time = 00:00:35
# Epoch [12/15], Step [200/2142], Loss: 0.1029, Accuracy: 0.9625, time = 00:00:35
# Epoch [12/15], Step [300/2142], Loss: 0.1072, Accuracy: 0.9583, time = 00:00:35
# Epoch [12/15], Step [400/2142], Loss: 0.1982, Accuracy: 0.9603, time = 00:00:35
# Epoch [12/15], Step [500/2142], Loss: 0.1498, Accuracy: 0.9590, time = 00:00:35
# Epoch [12/15], Step [600/2142], Loss: 0.0151, Accuracy: 0.9599, time = 00:00:35
# Epoch [12/15], Step [700/2142], Loss: 0.1530, Accuracy: 0.9587, time = 00:00:35
# Epoch [12/15], Step [800/2142], Loss: 0.2104, Accuracy: 0.9598, time = 00:00:35
# Epoch [12/15], Step [900/2142], Loss: 0.1097, Accuracy: 0.9594, time = 00:00:35
# Epoch [12/15], Step [1000/2142], Loss: 0.1834, Accuracy: 0.9591, time = 00:00:35
# Epoch [12/15], Step [1100/2142], Loss: 0.0067, Accuracy: 0.9591, time = 00:00:35
# Epoch [12/15], Step [1200/2142], Loss: 0.1445, Accuracy: 0.9585, time = 00:00:35
# Epoch [12/15], Step [1300/2142], Loss: 0.2008, Accuracy: 0.9582, time = 00:00:35
# Epoch [12/15], Step [1400/2142], Loss: 0.1688, Accuracy: 0.9578, time = 00:00:35
# Epoch [12/15], Step [1500/2142], Loss: 0.0256, Accuracy: 0.9574, time = 00:00:35
# Epoch [12/15], Step [1600/2142], Loss: 0.1475, Accuracy: 0.9569, time = 00:00:35
# Epoch [12/15], Step [1700/2142], Loss: 0.1091, Accuracy: 0.9564, time = 00:00:35
# Epoch [12/15], Step [1800/2142], Loss: 0.0583, Accuracy: 0.9562, time = 00:00:35
# Epoch [12/15], Step [1900/2142], Loss: 0.0372, Accuracy: 0.9561, time = 00:00:35
# Epoch [12/15], Step [2000/2142], Loss: 0.2700, Accuracy: 0.9557, time = 00:00:35
# Epoch [12/15], Step [2100/2142], Loss: 0.1297, Accuracy: 0.9558, time = 00:00:35
# Epoch 12/15, Train Loss: 0.1226, Train Accuracy: 0.9560, Val Loss: 1.2276, Val Accuracy: 0.7371, Time Spent = 00:12:59
# Epoch [13/15], Step [100/2142], Loss: 0.0022, Accuracy: 0.9769, time = 00:00:35
# Epoch [13/15], Step [200/2142], Loss: 0.0714, Accuracy: 0.9681, time = 00:00:35
# Epoch [13/15], Step [300/2142], Loss: 0.1236, Accuracy: 0.9652, time = 00:00:35
# Epoch [13/15], Step [400/2142], Loss: 0.0915, Accuracy: 0.9642, time = 00:00:35
# Epoch [13/15], Step [500/2142], Loss: 0.0190, Accuracy: 0.9634, time = 00:00:35
# Epoch [13/15], Step [600/2142], Loss: 0.0787, Accuracy: 0.9636, time = 00:00:35
# Epoch [13/15], Step [700/2142], Loss: 0.1441, Accuracy: 0.9632, time = 00:00:35
# Epoch [13/15], Step [800/2142], Loss: 0.0250, Accuracy: 0.9626, time = 00:00:35
# Epoch [13/15], Step [900/2142], Loss: 0.3800, Accuracy: 0.9620, time = 00:00:35
# Epoch [13/15], Step [1000/2142], Loss: 0.0554, Accuracy: 0.9611, time = 00:00:35
# Epoch [13/15], Step [1100/2142], Loss: 0.0045, Accuracy: 0.9609, time = 00:00:35
# Epoch [13/15], Step [1200/2142], Loss: 0.0314, Accuracy: 0.9611, time = 00:00:35
# Epoch [13/15], Step [1300/2142], Loss: 0.0124, Accuracy: 0.9620, time = 00:00:35
# Epoch [13/15], Step [1400/2142], Loss: 0.0681, Accuracy: 0.9618, time = 00:00:35
# Epoch [13/15], Step [1500/2142], Loss: 0.0371, Accuracy: 0.9618, time = 00:00:35
# Epoch [13/15], Step [1600/2142], Loss: 0.0830, Accuracy: 0.9617, time = 00:00:35
# Epoch [13/15], Step [1700/2142], Loss: 0.0349, Accuracy: 0.9610, time = 00:00:35
# Epoch [13/15], Step [1800/2142], Loss: 0.0054, Accuracy: 0.9611, time = 00:00:35
# Epoch [13/15], Step [1900/2142], Loss: 0.1194, Accuracy: 0.9608, time = 00:00:35
# Epoch [13/15], Step [2000/2142], Loss: 0.1550, Accuracy: 0.9607, time = 00:00:35
# Epoch [13/15], Step [2100/2142], Loss: 0.0183, Accuracy: 0.9607, time = 00:00:35
# Epoch 13/15, Train Loss: 0.1087, Train Accuracy: 0.9604, Val Loss: 1.1987, Val Accuracy: 0.7413, Time Spent = 00:13:00
# Epoch [14/15], Step [100/2142], Loss: 0.0587, Accuracy: 0.9669, time = 00:00:35
# Epoch [14/15], Step [200/2142], Loss: 0.2345, Accuracy: 0.9688, time = 00:00:35
# Epoch [14/15], Step [300/2142], Loss: 0.5991, Accuracy: 0.9681, time = 00:00:35
# Epoch [14/15], Step [400/2142], Loss: 0.0157, Accuracy: 0.9673, time = 00:00:35
# Epoch [14/15], Step [500/2142], Loss: 0.0221, Accuracy: 0.9660, time = 00:00:35
# Epoch [14/15], Step [600/2142], Loss: 0.0091, Accuracy: 0.9652, time = 00:00:35
# Epoch [14/15], Step [700/2142], Loss: 0.4540, Accuracy: 0.9646, time = 00:00:35
# Epoch [14/15], Step [800/2142], Loss: 0.0074, Accuracy: 0.9652, time = 00:00:35
# Epoch [14/15], Step [900/2142], Loss: 0.0093, Accuracy: 0.9653, time = 00:00:35
# Epoch [14/15], Step [1000/2142], Loss: 0.1785, Accuracy: 0.9637, time = 00:00:35
# Epoch [14/15], Step [1100/2142], Loss: 0.3667, Accuracy: 0.9641, time = 00:00:35
# Epoch [14/15], Step [1200/2142], Loss: 0.2904, Accuracy: 0.9640, time = 00:00:35
# Epoch [14/15], Step [1300/2142], Loss: 0.2143, Accuracy: 0.9638, time = 00:00:35
# Epoch [14/15], Step [1400/2142], Loss: 0.0230, Accuracy: 0.9639, time = 00:00:35
# Epoch [14/15], Step [1500/2142], Loss: 0.0045, Accuracy: 0.9642, time = 00:00:35
# Epoch [14/15], Step [1600/2142], Loss: 0.0166, Accuracy: 0.9640, time = 00:00:35
# Epoch [14/15], Step [1700/2142], Loss: 0.0893, Accuracy: 0.9639, time = 00:00:35
# Epoch [14/15], Step [1800/2142], Loss: 0.0957, Accuracy: 0.9637, time = 00:00:35
# Epoch [14/15], Step [1900/2142], Loss: 0.0501, Accuracy: 0.9640, time = 00:00:35
# Epoch [14/15], Step [2000/2142], Loss: 0.1250, Accuracy: 0.9639, time = 00:00:35
# Epoch [14/15], Step [2100/2142], Loss: 0.2922, Accuracy: 0.9640, time = 00:00:35
# Epoch 14/15, Train Loss: 0.0998, Train Accuracy: 0.9638, Val Loss: 1.1855, Val Accuracy: 0.7361, Time Spent = 00:13:00
# Epoch [15/15], Step [100/2142], Loss: 0.0180, Accuracy: 0.9750, time = 00:00:35
# Epoch [15/15], Step [200/2142], Loss: 0.0115, Accuracy: 0.9738, time = 00:00:35
# Epoch [15/15], Step [300/2142], Loss: 0.0847, Accuracy: 0.9727, time = 00:00:35
# Epoch [15/15], Step [400/2142], Loss: 0.0735, Accuracy: 0.9725, time = 00:00:35
# Epoch [15/15], Step [500/2142], Loss: 0.2921, Accuracy: 0.9718, time = 00:00:35
# Epoch [15/15], Step [600/2142], Loss: 0.1355, Accuracy: 0.9699, time = 00:00:35
# Epoch [15/15], Step [700/2142], Loss: 0.0095, Accuracy: 0.9700, time = 00:00:35
# Epoch [15/15], Step [800/2142], Loss: 0.2527, Accuracy: 0.9695, time = 00:00:35
# Epoch [15/15], Step [900/2142], Loss: 0.0312, Accuracy: 0.9699, time = 00:00:35
# Epoch [15/15], Step [1000/2142], Loss: 0.2102, Accuracy: 0.9689, time = 00:00:35
# Epoch [15/15], Step [1100/2142], Loss: 0.0248, Accuracy: 0.9684, time = 00:00:35
# Epoch [15/15], Step [1200/2142], Loss: 0.1650, Accuracy: 0.9683, time = 00:00:35
# Epoch [15/15], Step [1300/2142], Loss: 0.1737, Accuracy: 0.9689, time = 00:00:35
# Epoch [15/15], Step [1400/2142], Loss: 0.0518, Accuracy: 0.9688, time = 00:00:35
# Epoch [15/15], Step [1500/2142], Loss: 0.0425, Accuracy: 0.9694, time = 00:00:35
# Epoch [15/15], Step [1600/2142], Loss: 0.0230, Accuracy: 0.9693, time = 00:00:35
# Epoch [15/15], Step [1700/2142], Loss: 0.0034, Accuracy: 0.9696, time = 00:00:35
# Epoch [15/15], Step [1800/2142], Loss: 0.2265, Accuracy: 0.9693, time = 00:00:35
# Epoch [15/15], Step [1900/2142], Loss: 0.2559, Accuracy: 0.9694, time = 00:00:35
# Epoch [15/15], Step [2000/2142], Loss: 0.0376, Accuracy: 0.9694, time = 00:00:35
# Epoch [15/15], Step [2100/2142], Loss: 0.0590, Accuracy: 0.9687, time = 00:00:35
# Epoch 15/15, Train Loss: 0.0868, Train Accuracy: 0.9690, Val Loss: 1.2687, Val Accuracy: 0.7479, Time Spent = 00:12:59

# %%
# Evaluation
def evaluate_model(model, test_loader):
    model.eval()
    predictions, true_labels = [], []
    with torch.no_grad():
        for batch in test_loader:
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            text_length = batch["text_length"].to(device)
            language = batch["language"].to(device)

            outputs = model(input_ids, attention_mask, text_length, language)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            labels = batch["labels"].cpu().numpy()

            predictions.extend(preds)
            true_labels.extend(labels)

    print(classification_report(true_labels, predictions, target_names=label_map.keys()))

# %%
evaluate_model(model, test_loader)
# Out:
# <ipython-input-17-47be11e0a1ba>:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
#               precision    recall  f1-score   support
#
#     Negative       0.77      0.75      0.76      1271
#      Neutral       0.63      0.64      0.63      1291
#     Positive       0.84      0.84      0.84      1669
#
#     accuracy                           0.75      4231
#    macro avg       0.75      0.74      0.75      4231
# weighted avg       0.75      0.75      0.75      4231

# %%
# Predict custom input
def predict_sentiment(text, model, tokenizer):
    text_length = len(text)
    language = detect_dominant_language(text)
    language_encoded = language_map[language]

    model.eval()
    with torch.no_grad():
        encoding = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=character_limit).to(device)
        text_length_tensor = torch.tensor([text_length], dtype=torch.float32).to(device)
        language_tensor = torch.tensor([language_encoded], dtype=torch.long).to(device)

        output = model(encoding["input_ids"], encoding["attention_mask"], text_length_tensor, language_tensor)
        prediction = torch.argmax(output, dim=1).item()
        return list(label_map.keys())[prediction]

# %%
user_input = "আপনি আমাকে ভোটকা বলতে পারেন না"
sentiment = predict_sentiment(user_input, model, tokenizer)
print(f"Predicted Sentiment: {sentiment}")
# Out:
# Predicted Sentiment: Negative

# %%
user_input = "জয় বাংলা"
sentiment = predict_sentiment(user_input, model, tokenizer)
print(f"Predicted Sentiment: {sentiment}")
# Out:
# Predicted Sentiment: Positive

# %% [markdown]
# Fun fact is if we train our model using option 3 dataset, it would predict জয় বাংলা as negative! because it has updated data for training!!

# %% [markdown]
# for easy checking, below examples are generated from chatgpt

# %%
sentences = [
    # Positive Sentences
    {"text": "আমি আজ খুব খুশি।", "language": "Bangla", "sentiment": "Positive"},  # I'm very happy today.
    {"text": "आज का दिन बहुत अच्छा है।", "language": "Hindi", "sentiment": "Positive"},  # Today is a very good day.
    {"text": "I am so excited about the results.", "language": "English", "sentiment": "Positive"},
    {"text": "তোমার কাজ সত্যিই অসাধারণ!", "language": "Bangla", "sentiment": "Positive"},  # Your work is truly amazing!
    {"text": "यह मेरे जीवन का सबसे अच्छा समय है।", "language": "Hindi", "sentiment": "Positive"},  # This is the best time of my life.
    {"text": "The weather is absolutely delightful.", "language": "English", "sentiment": "Positive"},
    {"text": "তোমাকে পেয়ে আমি সত্যিই ভাগ্যবান।", "language": "Bangla", "sentiment": "Positive"},  # I'm truly lucky to have you.
    {"text": "आपकी मदद से मेरा काम आसान हो गया।", "language": "Hindi", "sentiment": "Positive"},  # Your help made my work easier.
    {"text": "I really appreciate everything you've done for me.", "language": "English", "sentiment": "Positive"},
    {"text": "আমার জীবনে আজ একটা নতুন অধ্যায় শুরু হলো।", "language": "Bangla", "sentiment": "Positive"},  # A new chapter started in my life today.
    {"text": "यह सफलता मेरे कठिन परिश्रम का परिणाम है।", "language": "Hindi", "sentiment": "Positive"},  # This success is the result of my hard work.
    {"text": "I feel incredibly grateful for this opportunity.", "language": "English", "sentiment": "Positive"},

    # Neutral Sentences
    {"text": "আমি দুপুরে ভাত খেয়েছি।", "language": "Bangla", "sentiment": "Neutral"},  # I had rice for lunch.
    {"text": "यह एक सामान्य दिन है।", "language": "Hindi", "sentiment": "Neutral"},  # It's a normal day.
    {"text": "The report was submitted on time.", "language": "English", "sentiment": "Neutral"},
    {"text": "তোমার চিঠি আজ সকালে পেলাম।", "language": "Bangla", "sentiment": "Neutral"},  # I received your letter this morning.
    {"text": "मुझे अभी कुछ कहना नहीं है।", "language": "Hindi", "sentiment": "Neutral"},  # I don't have anything to say right now.
    {"text": "The book is on the table.", "language": "English", "sentiment": "Neutral"},
    {"text": "আজকের আবহাওয়া ভালো।", "language": "Bangla", "sentiment": "Neutral"},  # Today's weather is fine.
    {"text": "मैंने सुबह चाय पी।", "language": "Hindi", "sentiment": "Neutral"},  # I had tea in the morning.
    {"text": "The meeting will start at 3 PM.", "language": "English", "sentiment": "Neutral"},
    {"text": "আমি আজ বই পড়ছি।", "language": "Bangla", "sentiment": "Neutral"},  # I am reading a book today.
    {"text": "मुझे नए कार्यक्रम के बारे में बताया गया।", "language": "Hindi", "sentiment": "Neutral"},  # I was informed about the new program.
    {"text": "There are no updates about the project yet.", "language": "English", "sentiment": "Neutral"},

    # Strongly Negative Sentences
    {"text": "আমি এত হতাশ যে আমি আর সহ্য করতে পারছি না।", "language": "Bangla", "sentiment": "Negative"},  # I am so frustrated that I can't take it anymore.
    {"text": "यह सबसे बेकार अनुभव था।", "language": "Hindi", "sentiment": "Negative"},  # This was the worst experience ever.
    {"text": "I hate how everything is falling apart in my life.", "language": "English", "sentiment": "Negative"},
    {"text": "তোমার আচরণ আমাকে চরম অপমানিত করেছে।", "language": "Bangla", "sentiment": "Negative"},  # Your behavior has deeply insulted me.
    {"text": "यह एक बड़ी गलती थी, और अब मुझे पछतावा हो रहा है।", "language": "Hindi", "sentiment": "Negative"},  # It was a big mistake, and I regret it now.
    {"text": "This is the most disappointing service I have ever received.", "language": "English", "sentiment": "Negative"},
    {"text": "এই পরিস্থিতি সম্পূর্ণ অগ্রহণযোগ্য।", "language": "Bangla", "sentiment": "Negative"},  # This situation is completely unacceptable.
    {"text": "आपकी लापरवाही ने सब बर्बाद कर दिया।", "language": "Hindi", "sentiment": "Negative"},  # Your carelessness has ruined everything.
    {"text": "I feel like giving up because nothing is going right.", "language": "English", "sentiment": "Negative"},
    {"text": "আমি নিজেকে সম্পূর্ণ ব্যর্থ মনে করছি।", "language": "Bangla", "sentiment": "Negative"},  # I feel like a complete failure.
    {"text": "मुझे अपने जीवन में कुछ भी अच्छा नहीं दिख रहा।", "language": "Hindi", "sentiment": "Negative"},  # I can't see anything good in my life.
    {"text": "Why does everything I do turn into a disaster?", "language": "English", "sentiment": "Negative"},
]

# Add more strongly negative examples
for i in range(15):
    sentences.append(
        {"text": f"এটা আমার জীবনের সবচেয়ে খারাপ দিন {i+1}।", "language": "Bangla", "sentiment": "Negative"}  # This is the worst day of my life {i+1}.
    )
    sentences.append(
        {"text": f"यह मेरी सबसे बड़ी असफलता है {i+1}।", "language": "Hindi", "sentiment": "Negative"}  # This is my biggest failure {i+1}.
    )
    sentences.append(
        {"text": f"This is unacceptable and I feel cheated {i+1}.", "language": "English", "sentiment": "Negative"}
    )

# %%
results = []

# Predict sentiments for the dataset
for sentence in sentences:
    predicted_sentiment = predict_sentiment(sentence["text"], model, tokenizer)
    results.append({
        "text": sentence["text"],
        "language": sentence["language"],
        "true_sentiment": sentence["sentiment"],
        "predicted_sentiment": predicted_sentiment
    })

# Display results
for res in results:
    print(f"Text: {res['text']}")
    print(f"Language: {res['language']}")
    print(f"True Sentiment: {res['true_sentiment']}")
    print(f"Predicted Sentiment: {res['predicted_sentiment']}")
    print("-" * 50)
# Out:
# Text: আমি আজ খুব খুশি।
# Language: Bangla
# True Sentiment: Positive
# Predicted Sentiment: Positive
# --------------------------------------------------
# Text: आज का दिन बहुत अच्छा है।
# Language: Hindi
# True Sentiment: Positive
# Predicted Sentiment: Positive
# --------------------------------------------------
# Text: I am so excited about the results.
# Language: English
# True Sentiment: Positive
# Predicted Sentiment: Positive
# --------------------------------------------------
# Text: তোমার কাজ সত্যিই অসাধারণ!
# Language: Bangla
# True Sentiment: Positive
# Predicted Sentiment: Positive
# --------------------------------------------------
# Text: यह मेरे जीवन का सबसे अच्छा समय है।
# Language: Hindi
# True Sentiment: Positive
# Predicted Sentiment: Positive
# --------------------------------------------------
# Text: The weather is absolutely delightful.
# Language: English
# True Sentiment: Positive
# Predicted Sentiment: Positive
# --------------------------------------------------
# Text: তোমাকে পেয়ে আমি সত্যিই ভাগ্যবান।
# Language: Bangla
# True Sentiment: Positive
# Predicted Sentiment: Positive
# --------------------------------------------------
# Text: आपकी मदद से मेरा काम आसान हो गया।
# Language: Hindi
# True Sentiment: Positive
# Predicted Sentiment: Positive
# --------------------------------------------------
# Text: I really appreciate everything you've done for me.
# Language: English
# True Sentiment: Positive
# Predicted Sentiment: Positive
# --------------------------------------------------
# Text: আমার জীবনে আজ একটা নতুন অধ্যায় শুরু হলো।
# Language: Bangla
# True Sentiment: Positive
# Predicted Sentiment: Positive
# --------------------------------------------------
# Text: यह सफलता मेरे कठिन परिश्रम का परिणाम है।
# Language: Hindi
# True Sentiment: Positive
# Predicted Sentiment: Positive
# --------------------------------------------------
# Text: I feel incredibly grateful for this opportunity.
# Language: English
# True Sentiment: Positive
# Predicted Sentiment: Positive
# --------------------------------------------------
# Text: আমি দুপুরে ভাত খেয়েছি।
# Language: Bangla
# True Sentiment: Neutral
# Predicted Sentiment: Neutral
# --------------------------------------------------
# Text: यह एक सामान्य दिन है।
# Language: Hindi
# True Sentiment: Neutral
# Predicted Sentiment: Neutral
# --------------------------------------------------
# Text: The report was submitted on time.
# Language: English
# True Sentiment: Neutral
# Predicted Sentiment: Positive
# --------------------------------------------------
# Text: তোমার চিঠি আজ সকালে পেলাম।
# Language: Bangla
# True Sentiment: Neutral
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: मुझे अभी कुछ कहना नहीं है।
# Language: Hindi
# True Sentiment: Neutral
# Predicted Sentiment: Neutral
# --------------------------------------------------
# Text: The book is on the table.
# Language: English
# True Sentiment: Neutral
# Predicted Sentiment: Positive
# --------------------------------------------------
# Text: আজকের আবহাওয়া ভালো।
# Language: Bangla
# True Sentiment: Neutral
# Predicted Sentiment: Positive
# --------------------------------------------------
# Text: मैंने सुबह चाय पी।
# Language: Hindi
# True Sentiment: Neutral
# Predicted Sentiment: Neutral
# --------------------------------------------------
# Text: The meeting will start at 3 PM.
# Language: English
# True Sentiment: Neutral
# Predicted Sentiment: Neutral
# --------------------------------------------------
# Text: আমি আজ বই পড়ছি।
# Language: Bangla
# True Sentiment: Neutral
# Predicted Sentiment: Positive
# --------------------------------------------------
# Text: मुझे नए कार्यक्रम के बारे में बताया गया।
# Language: Hindi
# True Sentiment: Neutral
# Predicted Sentiment: Neutral
# --------------------------------------------------
# Text: There are no updates about the project yet.
# Language: English
# True Sentiment: Neutral
# Predicted Sentiment: Neutral
# --------------------------------------------------
# Text: আমি এত হতাশ যে আমি আর সহ্য করতে পারছি না।
# Language: Bangla
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: यह सबसे बेकार अनुभव था।
# Language: Hindi
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: I hate how everything is falling apart in my life.
# Language: English
# True Sentiment: Negative
# Predicted Sentiment: Neutral
# --------------------------------------------------
# Text: তোমার আচরণ আমাকে চরম অপমানিত করেছে।
# Language: Bangla
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: यह एक बड़ी गलती थी, और अब मुझे पछतावा हो रहा है।
# Language: Hindi
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: This is the most disappointing service I have ever received.
# Language: English
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: এই পরিস্থিতি সম্পূর্ণ অগ্রহণযোগ্য।
# Language: Bangla
# True Sentiment: Negative
# Predicted Sentiment: Positive
# --------------------------------------------------
# Text: आपकी लापरवाही ने सब बर्बाद कर दिया।
# Language: Hindi
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: I feel like giving up because nothing is going right.
# Language: English
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: আমি নিজেকে সম্পূর্ণ ব্যর্থ মনে করছি।
# Language: Bangla
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: मुझे अपने जीवन में कुछ भी अच्छा नहीं दिख रहा।
# Language: Hindi
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: Why does everything I do turn into a disaster?
# Language: English
# True Sentiment: Negative
# Predicted Sentiment: Neutral
# --------------------------------------------------
# Text: এটা আমার জীবনের সবচেয়ে খারাপ দিন 1।
# Language: Bangla
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: यह मेरी सबसे बड़ी असफलता है 1।
# Language: Hindi
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: This is unacceptable and I feel cheated 1.
# Language: English
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: এটা আমার জীবনের সবচেয়ে খারাপ দিন 2।
# Language: Bangla
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: यह मेरी सबसे बड़ी असफलता है 2।
# Language: Hindi
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: This is unacceptable and I feel cheated 2.
# Language: English
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: এটা আমার জীবনের সবচেয়ে খারাপ দিন 3।
# Language: Bangla
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: यह मेरी सबसे बड़ी असफलता है 3।
# Language: Hindi
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: This is unacceptable and I feel cheated 3.
# Language: English
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: এটা আমার জীবনের সবচেয়ে খারাপ দিন 4।
# Language: Bangla
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: यह मेरी सबसे बड़ी असफलता है 4।
# Language: Hindi
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: This is unacceptable and I feel cheated 4.
# Language: English
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: এটা আমার জীবনের সবচেয়ে খারাপ দিন 5।
# Language: Bangla
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: यह मेरी सबसे बड़ी असफलता है 5।
# Language: Hindi
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: This is unacceptable and I feel cheated 5.
# Language: English
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: এটা আমার জীবনের সবচেয়ে খারাপ দিন 6।
# Language: Bangla
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: यह मेरी सबसे बड़ी असफलता है 6।
# Language: Hindi
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: This is unacceptable and I feel cheated 6.
# Language: English
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: এটা আমার জীবনের সবচেয়ে খারাপ দিন 7।
# Language: Bangla
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: यह मेरी सबसे बड़ी असफलता है 7।
# Language: Hindi
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: This is unacceptable and I feel cheated 7.
# Language: English
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: এটা আমার জীবনের সবচেয়ে খারাপ দিন 8।
# Language: Bangla
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: यह मेरी सबसे बड़ी असफलता है 8।
# Language: Hindi
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: This is unacceptable and I feel cheated 8.
# Language: English
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: এটা আমার জীবনের সবচেয়ে খারাপ দিন 9।
# Language: Bangla
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: यह मेरी सबसे बड़ी असफलता है 9।
# Language: Hindi
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: This is unacceptable and I feel cheated 9.
# Language: English
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: এটা আমার জীবনের সবচেয়ে খারাপ দিন 10।
# Language: Bangla
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: यह मेरी सबसे बड़ी असफलता है 10।
# Language: Hindi
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: This is unacceptable and I feel cheated 10.
# Language: English
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: এটা আমার জীবনের সবচেয়ে খারাপ দিন 11।
# Language: Bangla
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: यह मेरी सबसे बड़ी असफलता है 11।
# Language: Hindi
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: This is unacceptable and I feel cheated 11.
# Language: English
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: এটা আমার জীবনের সবচেয়ে খারাপ দিন 12।
# Language: Bangla
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: यह मेरी सबसे बड़ी असफलता है 12।
# Language: Hindi
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: This is unacceptable and I feel cheated 12.
# Language: English
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: এটা আমার জীবনের সবচেয়ে খারাপ দিন 13।
# Language: Bangla
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: यह मेरी सबसे बड़ी असफलता है 13।
# Language: Hindi
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: This is unacceptable and I feel cheated 13.
# Language: English
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: এটা আমার জীবনের সবচেয়ে খারাপ দিন 14।
# Language: Bangla
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: यह मेरी सबसे बड़ी असफलता है 14।
# Language: Hindi
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: This is unacceptable and I feel cheated 14.
# Language: English
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: এটা আমার জীবনের সবচেয়ে খারাপ দিন 15।
# Language: Bangla
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: यह मेरी सबसे बड़ी असफलता है 15।
# Language: Hindi
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
# Text: This is unacceptable and I feel cheated 15.
# Language: English
# True Sentiment: Negative
# Predicted Sentiment: Negative
# --------------------------------------------------
